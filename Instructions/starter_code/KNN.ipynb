# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in /Applications/anaconda3/envs/PythonWebMongo/lib/python3.6/site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in /Applications/anaconda3/envs/PythonWebMongo/lib/python3.6/site-packages (from sklearn) (0.21.2)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in /Applications/anaconda3/envs/PythonWebMongo/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.3.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /Applications/anaconda3/envs/PythonWebMongo/lib/python3.6/site-packages (from scikit-learn->sklearn) (0.13.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in /Applications/anaconda3/envs/PythonWebMongo/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.18.1)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in /Applications/anaconda3/envs/PythonWebMongo/lib/python3.6/site-packages (0.13.2)

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
#only keep features that don't include "err"
X= df[["koi_fpflag_nt", "koi_fpflag_ss", "koi_fpflag_co", "koi_fpflag_ec","koi_period", "koi_time0bk","koi_slogg", "koi_srad", "ra", "dec", "koi_kepmag"]]
y=df["koi_disposition"]
X.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_time0bk  koi_slogg  koi_srad         ra        dec  koi_kepmag
# 0   162.513840      4.467     0.927  291.93423  48.141651      15.347
# 1   175.850252      4.544     0.868  297.00482  48.134129      15.436
# 2   170.307565      4.564     0.791  285.53461  48.285210      15.597
# 3   171.595550      4.438     1.046  288.75488  48.226200      15.509
# 4   172.979370      4.486     0.972  296.28613  48.224670      15.714

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# [0.14609491 0.22487589 0.14829915 0.04851962 0.07400299 0.07537872
#  0.0569703  0.05592886 0.06010523 0.05454369 0.05528063]
# /Applications/anaconda3/envs/PythonWebMongo/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
# Keep the top ten features:
X= df[["koi_fpflag_nt", "koi_fpflag_ss", "koi_fpflag_co", "koi_period", "koi_time0bk","koi_slogg", "koi_srad", "ra", "koi_kepmag"]]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_period  koi_time0bk  \
# 4002              0              0              1   99.673478   219.334830
# 4246              0              1              0    0.592244   131.654831
# 548               0              1              1    9.991625   137.447816
# 3953              0              1              0  178.412990   218.225235
# 2362              0              0              0   45.294223   138.678725
#
#       koi_slogg  koi_srad         ra  koi_kepmag
# 4002      4.777     0.492  293.05801      15.801
# 4246      4.664     0.591  290.28094      15.653
# 548       4.338     1.096  301.04239      14.039
# 3953      4.346     1.148  288.32785      13.944
# 2362      4.347     1.044  285.67938      10.961

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
# Scale your data
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train_scaled, y_train)
print(f"Training Data Score: {knn.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {knn.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.8100324241846272
# Testing Data Score: 0.7814645308924485

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'n_neighbors': range(1, 10, 2),
             'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
             'p': [1,2]}
grid = GridSearchCV(knn, param_grid, verbose=3)

# %%
# Train the model with GridSearch
best_knn = grid.fit(X_train_scaled, y_train)
# Out:
# /Applications/anaconda3/envs/PythonWebMongo/lib/python3.6/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [CV] algorithm=auto, n_neighbors=1, p=1 ..............................
# [CV] .. algorithm=auto, n_neighbors=1, p=1, score=0.767, total=   0.1s
# [CV] algorithm=auto, n_neighbors=1, p=1 ..............................
# [CV] .. algorithm=auto, n_neighbors=1, p=1, score=0.777, total=   0.1s
# [CV] algorithm=auto, n_neighbors=1, p=1 ..............................
# [CV] .. algorithm=auto, n_neighbors=1, p=1, score=0.773, total=   0.1s
# [CV] algorithm=auto, n_neighbors=1, p=2 ..............................
# [CV] .. algorithm=auto, n_neighbors=1, p=2, score=0.760, total=   0.1s
# [CV] algorithm=auto, n_neighbors=1, p=2 ..............................
# [CV] .. algorithm=auto, n_neighbors=1, p=2, score=0.772, total=   0.1s
# [CV] algorithm=auto, n_neighbors=1, p=2 ..............................
# [CV] .. algorithm=auto, n_neighbors=1, p=2, score=0.773, total=   0.1s
# [CV] algorithm=auto, n_neighbors=3, p=1 ..............................
# [CV] .. algorithm=auto, n_neighbors=3, p=1, score=0.779, total=   0.1s
# [CV] algorithm=auto, n_neighbors=3, p=1 ..............................
# [CV] .. algorithm=auto, n_neighbors=3, p=1, score=0.781, total=   0.1s
# [CV] algorithm=auto, n_neighbors=3, p=1 ..............................
# [CV] .. algorithm=auto, n_neighbors=3, p=1, score=0.769, total=   0.1s
# [CV] algorithm=auto, n_neighbors=3, p=2 ..............................
# [CV] .. algorithm=auto, n_neighbors=3, p=2, score=0.784, total=   0.1s
# [CV] algorithm=auto, n_neighbors=3, p=2 ..............................
# [CV] .. algorithm=auto, n_neighbors=3, p=2, score=0.776, total=   0.1s
# [CV] algorithm=auto, n_neighbors=3, p=2 ..............................
# [CV] .. algorithm=auto, n_neighbors=3, p=2, score=0.769, total=   0.1s
# [CV] algorithm=auto, n_neighbors=5, p=1 ..............................
# [CV] .. algorithm=auto, n_neighbors=5, p=1, score=0.780, total=   0.1s
# [CV] algorithm=auto, n_neighbors=5, p=1 ..............................
# [CV] .. algorithm=auto, n_neighbors=5, p=1, score=0.777, total=   0.1s
# [CV] algorithm=auto, n_neighbors=5, p=1 ..............................
# [CV] .. algorithm=auto, n_neighbors=5, p=1, score=0.778, total=   0.1s
# [CV] algorithm=auto, n_neighbors=5, p=2 ..............................
# [CV] .. algorithm=auto, n_neighbors=5, p=2, score=0.785, total=   0.1s
# [CV] algorithm=auto, n_neighbors=5, p=2 ..............................
# [CV] .. algorithm=auto, n_neighbors=5, p=2, score=0.780, total=   0.1s
# [CV] algorithm=auto, n_neighbors=5, p=2 ..............................
# [CV] .. algorithm=auto, n_neighbors=5, p=2, score=0.761, total=   0.1s
# [CV] algorithm=auto, n_neighbors=7, p=1 ..............................
# [CV] .. algorithm=auto, n_neighbors=7, p=1, score=0.788, total=   0.1s
# [CV] algorithm=auto, n_neighbors=7, p=1 ..............................
# [CV] .. algorithm=auto, n_neighbors=7, p=1, score=0.774, total=   0.1s
# [CV] algorithm=auto, n_neighbors=7, p=1 ..............................
# [CV] .. algorithm=auto, n_neighbors=7, p=1, score=0.777, total=   0.1s
# [CV] algorithm=auto, n_neighbors=7, p=2 ..............................
# [CV] .. algorithm=auto, n_neighbors=7, p=2, score=0.792, total=   0.1s
# [CV] algorithm=auto, n_neighbors=7, p=2 ..............................
# [CV] .. algorithm=auto, n_neighbors=7, p=2, score=0.779, total=   0.1s
# [CV] algorithm=auto, n_neighbors=7, p=2 ..............................
# [CV] .. algorithm=auto, n_neighbors=7, p=2, score=0.764, total=   0.1s
# [CV] algorithm=auto, n_neighbors=9, p=1 ..............................
# [CV] .. algorithm=auto, n_neighbors=9, p=1, score=0.785, total=   0.1s
# [CV] algorithm=auto, n_neighbors=9, p=1 ..............................
# [CV] .. algorithm=auto, n_neighbors=9, p=1, score=0.777, total=   0.1s
# [CV] algorithm=auto, n_neighbors=9, p=1 ..............................
# [CV] .. algorithm=auto, n_neighbors=9, p=1, score=0.778, total=   0.1s
# [CV] algorithm=auto, n_neighbors=9, p=2 ..............................
# [CV] .. algorithm=auto, n_neighbors=9, p=2, score=0.793, total=   0.1s
# [CV] algorithm=auto, n_neighbors=9, p=2 ..............................
# [CV] .. algorithm=auto, n_neighbors=9, p=2, score=0.775, total=   0.1s
# [CV] algorithm=auto, n_neighbors=9, p=2 ..............................
# [CV] .. algorithm=auto, n_neighbors=9, p=2, score=0.769, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=1, p=1 .........................
# [CV]  algorithm=ball_tree, n_neighbors=1, p=1, score=0.767, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=1, p=1 .........................
# [CV]  algorithm=ball_tree, n_neighbors=1, p=1, score=0.777, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=1, p=1 .........................
# [CV]  algorithm=ball_tree, n_neighbors=1, p=1, score=0.773, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=1, p=2 .........................
# [CV]  algorithm=ball_tree, n_neighbors=1, p=2, score=0.760, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=1, p=2 .........................
# [CV]  algorithm=ball_tree, n_neighbors=1, p=2, score=0.772, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=1, p=2 .........................
# [CV]  algorithm=ball_tree, n_neighbors=1, p=2, score=0.773, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=3, p=1 .........................
# [CV]  algorithm=ball_tree, n_neighbors=3, p=1, score=0.779, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=3, p=1 .........................
# [CV]  algorithm=ball_tree, n_neighbors=3, p=1, score=0.781, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=3, p=1 .........................
# [CV]  algorithm=ball_tree, n_neighbors=3, p=1, score=0.769, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=3, p=2 .........................
# [CV]  algorithm=ball_tree, n_neighbors=3, p=2, score=0.784, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=3, p=2 .........................
# [CV]  algorithm=ball_tree, n_neighbors=3, p=2, score=0.776, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=3, p=2 .........................
# [CV]  algorithm=ball_tree, n_neighbors=3, p=2, score=0.769, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=5, p=1 .........................
# [CV]  algorithm=ball_tree, n_neighbors=5, p=1, score=0.780, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=5, p=1 .........................
# [CV]  algorithm=ball_tree, n_neighbors=5, p=1, score=0.777, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=5, p=1 .........................
# [CV]  algorithm=ball_tree, n_neighbors=5, p=1, score=0.778, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=5, p=2 .........................
# [CV]  algorithm=ball_tree, n_neighbors=5, p=2, score=0.785, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=5, p=2 .........................
# [CV]  algorithm=ball_tree, n_neighbors=5, p=2, score=0.780, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=5, p=2 .........................
# [CV]  algorithm=ball_tree, n_neighbors=5, p=2, score=0.761, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=7, p=1 .........................
# [CV]  algorithm=ball_tree, n_neighbors=7, p=1, score=0.788, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=7, p=1 .........................
# [CV]  algorithm=ball_tree, n_neighbors=7, p=1, score=0.774, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=7, p=1 .........................
# [CV]  algorithm=ball_tree, n_neighbors=7, p=1, score=0.777, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=7, p=2 .........................
# [CV]  algorithm=ball_tree, n_neighbors=7, p=2, score=0.792, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=7, p=2 .........................
# [CV]  algorithm=ball_tree, n_neighbors=7, p=2, score=0.779, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=7, p=2 .........................
# [CV]  algorithm=ball_tree, n_neighbors=7, p=2, score=0.764, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=9, p=1 .........................
# [CV]  algorithm=ball_tree, n_neighbors=9, p=1, score=0.785, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=9, p=1 .........................
# [CV]  algorithm=ball_tree, n_neighbors=9, p=1, score=0.777, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=9, p=1 .........................
# [CV]  algorithm=ball_tree, n_neighbors=9, p=1, score=0.778, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=9, p=2 .........................
# [CV]  algorithm=ball_tree, n_neighbors=9, p=2, score=0.793, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=9, p=2 .........................
# [CV]  algorithm=ball_tree, n_neighbors=9, p=2, score=0.775, total=   0.1s
# [CV] algorithm=ball_tree, n_neighbors=9, p=2 .........................
# [CV]  algorithm=ball_tree, n_neighbors=9, p=2, score=0.769, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=1, p=1 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=1, p=1, score=0.767, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=1, p=1 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=1, p=1, score=0.777, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=1, p=1 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=1, p=1, score=0.773, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=1, p=2 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=1, p=2, score=0.760, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=1, p=2 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=1, p=2, score=0.772, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=1, p=2 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=1, p=2, score=0.773, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=3, p=1 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=3, p=1, score=0.779, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=3, p=1 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=3, p=1, score=0.781, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=3, p=1 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=3, p=1, score=0.769, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=3, p=2 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=3, p=2, score=0.784, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=3, p=2 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=3, p=2, score=0.776, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=3, p=2 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=3, p=2, score=0.769, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=5, p=1 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=5, p=1, score=0.780, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=5, p=1 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=5, p=1, score=0.777, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=5, p=1 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=5, p=1, score=0.778, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=5, p=2 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=5, p=2, score=0.785, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=5, p=2 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=5, p=2, score=0.780, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=5, p=2 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=5, p=2, score=0.761, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=7, p=1 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=7, p=1, score=0.788, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=7, p=1 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=7, p=1, score=0.774, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=7, p=1 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=7, p=1, score=0.777, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=7, p=2 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=7, p=2, score=0.792, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=7, p=2 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=7, p=2, score=0.779, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=7, p=2 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=7, p=2, score=0.764, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=9, p=1 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=9, p=1, score=0.785, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=9, p=1 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=9, p=1, score=0.777, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=9, p=1 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=9, p=1, score=0.778, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=9, p=2 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=9, p=2, score=0.793, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=9, p=2 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=9, p=2, score=0.775, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=9, p=2 ...........................
# [CV]  algorithm=kd_tree, n_neighbors=9, p=2, score=0.769, total=   0.1s
# [CV] algorithm=brute, n_neighbors=1, p=1 .............................
# [CV] . algorithm=brute, n_neighbors=1, p=1, score=0.767, total=   0.1s
# [CV] algorithm=brute, n_neighbors=1, p=1 .............................
# [CV] . algorithm=brute, n_neighbors=1, p=1, score=0.777, total=   0.1s
# [CV] algorithm=brute, n_neighbors=1, p=1 .............................
# [CV] . algorithm=brute, n_neighbors=1, p=1, score=0.773, total=   0.1s
# [CV] algorithm=brute, n_neighbors=1, p=2 .............................
# [CV] . algorithm=brute, n_neighbors=1, p=2, score=0.760, total=   0.1s
# [CV] algorithm=brute, n_neighbors=1, p=2 .............................
# [CV] . algorithm=brute, n_neighbors=1, p=2, score=0.772, total=   0.1s
# [CV] algorithm=brute, n_neighbors=1, p=2 .............................
# [CV] . algorithm=brute, n_neighbors=1, p=2, score=0.773, total=   0.1s
# [CV] algorithm=brute, n_neighbors=3, p=1 .............................
# [CV] . algorithm=brute, n_neighbors=3, p=1, score=0.779, total=   0.1s
# [CV] algorithm=brute, n_neighbors=3, p=1 .............................
# [CV] . algorithm=brute, n_neighbors=3, p=1, score=0.781, total=   0.1s
# [CV] algorithm=brute, n_neighbors=3, p=1 .............................
# [CV] . algorithm=brute, n_neighbors=3, p=1, score=0.769, total=   0.1s
# [CV] algorithm=brute, n_neighbors=3, p=2 .............................
# [CV] . algorithm=brute, n_neighbors=3, p=2, score=0.784, total=   0.1s
# [CV] algorithm=brute, n_neighbors=3, p=2 .............................
# [CV] . algorithm=brute, n_neighbors=3, p=2, score=0.776, total=   0.1s
# [CV] algorithm=brute, n_neighbors=3, p=2 .............................
# [CV] . algorithm=brute, n_neighbors=3, p=2, score=0.769, total=   0.1s
# [CV] algorithm=brute, n_neighbors=5, p=1 .............................
# [CV] . algorithm=brute, n_neighbors=5, p=1, score=0.780, total=   0.2s
# [CV] algorithm=brute, n_neighbors=5, p=1 .............................
# [CV] . algorithm=brute, n_neighbors=5, p=1, score=0.777, total=   0.2s
# [CV] algorithm=brute, n_neighbors=5, p=1 .............................
# [CV] . algorithm=brute, n_neighbors=5, p=1, score=0.778, total=   0.2s
# [CV] algorithm=brute, n_neighbors=5, p=2 .............................
# [CV] . algorithm=brute, n_neighbors=5, p=2, score=0.785, total=   0.2s
# [CV] algorithm=brute, n_neighbors=5, p=2 .............................
# [CV] . algorithm=brute, n_neighbors=5, p=2, score=0.780, total=   0.2s
# [CV] algorithm=brute, n_neighbors=5, p=2 .............................
# [CV] . algorithm=brute, n_neighbors=5, p=2, score=0.761, total=   0.1s
# [CV] algorithm=brute, n_neighbors=7, p=1 .............................
# [CV] . algorithm=brute, n_neighbors=7, p=1, score=0.788, total=   0.2s
# [CV] algorithm=brute, n_neighbors=7, p=1 .............................
# [CV] . algorithm=brute, n_neighbors=7, p=1, score=0.774, total=   0.2s
# [CV] algorithm=brute, n_neighbors=7, p=1 .............................
# [CV] . algorithm=brute, n_neighbors=7, p=1, score=0.777, total=   0.2s
# [CV] algorithm=brute, n_neighbors=7, p=2 .............................
# [CV] . algorithm=brute, n_neighbors=7, p=2, score=0.792, total=   0.2s
# [CV] algorithm=brute, n_neighbors=7, p=2 .............................
# [CV] . algorithm=brute, n_neighbors=7, p=2, score=0.779, total=   0.2s
# [CV] algorithm=brute, n_neighbors=7, p=2 .............................
# [CV] . algorithm=brute, n_neighbors=7, p=2, score=0.764, total=   0.2s
# [CV] algorithm=brute, n_neighbors=9, p=1 .............................
# [CV] . algorithm=brute, n_neighbors=9, p=1, score=0.785, total=   0.2s
# [CV] algorithm=brute, n_neighbors=9, p=1 .............................
# [CV] . algorithm=brute, n_neighbors=9, p=1, score=0.777, total=   0.2s
# [CV] algorithm=brute, n_neighbors=9, p=1 .............................
# [CV] . algorithm=brute, n_neighbors=9, p=1, score=0.778, total=   0.2s
# [CV] algorithm=brute, n_neighbors=9, p=2 .............................
# [CV] . algorithm=brute, n_neighbors=9, p=2, score=0.793, total=   0.2s
# [CV] algorithm=brute, n_neighbors=9, p=2 .............................
# [CV] . algorithm=brute, n_neighbors=9, p=2, score=0.775, total=   0.2s
# [CV] algorithm=brute, n_neighbors=9, p=2 .............................
# [CV] . algorithm=brute, n_neighbors=9, p=2, score=0.769, total=   0.2s
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:   12.5s finished

# %%
print(best_knn.best_params_)
print(f"Best Fit GridSearch Score: {best_knn.best_score_}")
print(f"Best Fit Testing Data Score: {best_knn.score(X_test_scaled, y_test)}")
print(f"Unfitted Testing Data Score: {knn.score(X_test_scaled, y_test)}")
# Out:
# {'algorithm': 'auto', 'n_neighbors': 9, 'p': 1}
# Best Fit GridSearch Score: 0.7800877360289911
# Best Fit Testing Data Score: 0.782608695652174
# Unfitted Testing Data Score: 0.7814645308924485

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'your_name.sav'
joblib.dump(your_model, filename)
